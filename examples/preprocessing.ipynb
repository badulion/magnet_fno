# %%
# !pip install pandas
# !pip install h5py
# !pip install trimesh
# !pip install einops
# !pip install libigl
# !pip install rtree
# !pip install scipy
# !pip install tqdm
# Out:
# Requirement already satisfied: pandas in /Users/mariusbohn/Documents/Studium/MA/ma_bohn/.venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/mariusbohn/Documents/Studium/MA/ma_bohn/.venv/lib/python3.12/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mariusbohn/Documents/Studium/MA/ma_bohn/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mariusbohn/Documents/Studium/MA/ma_bohn/.venv/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mariusbohn/Documents/Studium/MA/ma_bohn/.venv/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /Users/mariusbohn/Documents/Studium/MA/ma_bohn/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: h5py in /Users/mariusbohn/Documents/Studium/MA/ma_bohn/.venv/lib/python3.12/site-packages (3.12.1)
# Requirement already satisfied: numpy>=1.19.3 in /Users/mariusbohn/Documents/Studium/MA/ma_bohn/.venv/lib/python3.12/site-packages (from h5py) (2.1.3)
# Requirement already satisfied: trimesh in /Users/mariusbohn/Documents/Studium/MA/ma_bohn/.venv/lib/python3.12/site-packages (4.5.2)
# Requirement already satisfied: numpy>=1.20 in /Users/mariusbohn/Documents/Studium/MA/ma_bohn/.venv/lib/python3.12/site-packages (from trimesh) (2.1.3)
# Requirement already satisfied: einops in /Users/mariusbohn/Documents/Studium/MA/ma_bohn/.venv/lib/python3.12/site-packages (0.8.0)
# Requirement already satisfied: libigl in /Users/mariusbohn/Documents/Studium/MA/ma_bohn/.venv/lib/python3.12/site-packages (2.5.1)
# Requirement already satisfied: numpy in /Users/mariusbohn/Documents/Studium/MA/ma_bohn/.venv/lib/python3.12/site-packages (from libigl) (2.1.3)
# Requirement already satisfied: scipy in /Users/mariusbohn/Documents/Studium/MA/ma_bohn/.venv/lib/python3.12/site-packages (from libigl) (1.14.1)
# Requirement already satisfied: rtree in /Users/mariusbohn/Documents/Studium/MA/ma_bohn/.venv/lib/python3.12/site-packages (1.3.0)
# Requirement already satisfied: scipy in /Users/mariusbohn/Documents/Studium/MA/ma_bohn/.venv/lib/python3.12/site-packages (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /Users/mariusbohn/Documents/Studium/MA/ma_bohn/.venv/lib/python3.12/site-packages (from scipy) (2.1.3)
# Collecting tqdm
#   Downloading tqdm-4.67.0-py3-none-any.whl.metadata (57 kB)
# Downloading tqdm-4.67.0-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.67.0

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('..')

# %%
import numpy as np

from src.preprocessing.preprocessing import GridPreprocessing, PointPreprocessing

# %%
preprocessor = GridPreprocessing(
    "../data/raw/batch_6",
    "../data/processed/batch_6",
    field_dtype=np.float32,
    x_min=-240,
    x_max=240,
    y_min=-220,
    y_max=220,
    z_min=-250,
    z_max=250
)

# %%
preprocessor.process_simulations()
#preprocessor.process_simulations(simulation_names=['children_0_tubes_0_id_7151', 'children_0_tubes_0_id_7586', 'children_0_tubes_0_id_9619'])
# Out:
# 100%|██████████| 44/44 [03:14<00:00,  4.41s/it, done=children_3_tubes_8_id_5380]

# %%
point_preprocessor = PointPreprocessing(
    "../data/raw/batch_6",
    "../data/processed/batch_6",
    field_dtype=np.float16
)

# %%
point_preprocessor.process_simulations()
